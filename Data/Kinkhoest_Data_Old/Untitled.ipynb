# %%
import pandas as pd
import numpy as np

import sys
sys.path.append("../../Central_Folder")
sys.path.append("../../Data/Map")

from Locations import monthly_transfrom, make_df_shapefile

# %%
dataframe = pd.read_csv('sample.csv', sep=';')
dataframe.head()
# Out:
#   Date of Onset  PostCode Hospitalised  Identifier        Date  \
# 0           NaN    5062.0    Not known       76799  24-12-2014
# 1     18-8-2011    5021.0           No       34080    5-9-2011
# 2           NaN    5256.0    Not known       96671  25-11-2015
# 3     14-9-2012    5343.0           No       50243   9-10-2012
# 4     27-2-2014    5231.0           No       65997   24-3-2014
#
#   Meldingsplichtige ziekte  Gender  Age in Years (at date of onset)  \
# 0    Kinkhoest (Pertussis)  Female                               72
# 1    Kinkhoest (Pertussis)  Female                               44
# 2    Kinkhoest (Pertussis)  Female                               44
# 3    Kinkhoest (Pertussis)  Female                               10
# 4    Kinkhoest (Pertussis)    Male                               13
#
#    Age in Months (if a baby)
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# ...

# %%
import os

cwd = os.getcwd()
print(cwd)
# Out:
# C:\Users\ekoulier\Desktop\Infectious Diseases\Data\Kinkhoest_Data_Old

# %%
dataset = monthly_transfrom(dataframe)

# %%
m = monthly_transfrom(dataframe)
m.first_method()
m.find_mun()

# %%
dataset.df.head()
# Out:
#   Date of Onset  PostCode Hospitalised  Identifier        Date  \
# 0           NaN    5062.0    Not known       76799  24-12-2014
# 1     18-8-2011    5021.0           No       34080    5-9-2011
# 2           NaN    5256.0    Not known       96671  25-11-2015
# 3     14-9-2012    5343.0           No       50243   9-10-2012
# 4     27-2-2014    5231.0           No       65997   24-3-2014
#
#   Meldingsplichtige ziekte  Gender  Age in Years (at date of onset)  \
# 0    Kinkhoest (Pertussis)  Female                               72
# 1    Kinkhoest (Pertussis)  Female                               44
# 2    Kinkhoest (Pertussis)  Female                               44
# 3    Kinkhoest (Pertussis)  Female                               10
# 4    Kinkhoest (Pertussis)    Male                               13
#
#    Age in Months (if a baby)
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# ...

# %%
dataset.first_method()

# %%
dataset.find_mun()

# %%
dataset.df.head()
# Out:
#   Date of Onset PostCode Hospitalised  Identifier    Date  \
# 0           NaN     5062    Not known       76799 2014-12
# 1           NaN     5062    Not known       88816 2015-06
# 2     10-7-2011     5062           No       34594 2011-09
# 3     30-7-2011     5062           No       34660 2011-09
# 4     12-9-2012     5062           No       49892 2012-10
#
#   Meldingsplichtige ziekte  Gender  Age in Years (at date of onset)  \
# 0    Kinkhoest (Pertussis)  Female                               72
# 1    Kinkhoest (Pertussis)    Male                                9
# 2    Kinkhoest (Pertussis)    Male                               15
# 3    Kinkhoest (Pertussis)  Female                               16
# 4    Kinkhoest (Pertussis)    Male                               78
#
#    Age in Months (if a baby)  Count Municipality
# 0                          0      1   Oisterwijk
# 1                          0      1   Oisterwijk
# 2                          0      1   Oisterwijk
# ...

# %%
dataset.find_GGD()

# %%
dataset.df.head()
# Out:
#   Date of Onset PostCode Hospitalised  Identifier    Date  \
# 0           NaN     5062    Not known       76799 2014-12
# 1           NaN     5062    Not known       88816 2015-06
# 2     10-7-2011     5062           No       34594 2011-09
# 3     30-7-2011     5062           No       34660 2011-09
# 4     12-9-2012     5062           No       49892 2012-10
#
#   Meldingsplichtige ziekte  Gender  Age in Years (at date of onset)  \
# 0    Kinkhoest (Pertussis)  Female                               72
# 1    Kinkhoest (Pertussis)    Male                                9
# 2    Kinkhoest (Pertussis)    Male                               15
# 3    Kinkhoest (Pertussis)  Female                               16
# 4    Kinkhoest (Pertussis)    Male                               78
#
#    Age in Months (if a baby)  Count Municipality  GGD
# 0                          0      1   Oisterwijk  HVB
# 1                          0      1   Oisterwijk  HVB
# ...

# %%
k = dataset.monthly_municipality()

# %%
k.head()
# Out:
#        Municipality  2010-01  2010-02  2010-03  2010-04  2010-05  2010-06  \
# 0  's-Hertogenbosch        4        4        1        1        3        1
# 1      Alphen-Chaam        0        0        0        0        0        0
# 2          Bernheze        4        1        0        0        1        1
# 3            Boekel        0        0        0        0        1        1
# 4           Boxmeer        0        1        2        1        3        1
#
#    2010-07  2010-08  2010-09   ...     2016-08  2016-09  2016-10  2016-11  \
# 0        3        5        2   ...           6       13        1        3
# 1        0        0        0   ...           0        0        0        0
# 2        0        0        0   ...           2        3        3        2
# 3        0        0        1   ...           0        0        0        0
# 4        0        4        0   ...           1        2        3        0
#
#    2016-12  2017-01  2017-02  2017-03  2017-04  2017-05
# ...

# %%
k.columns
# Out:
# Index(['Municipality', '2010-01', '2010-02', '2010-03', '2010-04', '2010-05',
#        '2010-06', '2010-07', '2010-08', '2010-09', '2010-10', '2010-11',
#        '2010-12', '2011-01', '2011-02', '2011-03', '2011-04', '2011-05',
#        '2011-06', '2011-07', '2011-08', '2011-09', '2011-10', '2011-11',
#        '2011-12', '2012-01', '2012-02', '2012-03', '2012-04', '2012-05',
#        '2012-06', '2012-07', '2012-08', '2012-09', '2012-10', '2012-11',
#        '2012-12', '2013-01', '2013-02', '2013-03', '2013-04', '2013-05',
#        '2013-06', '2013-07', '2013-08', '2013-09', '2013-10', '2013-11',
#        '2013-12', '2014-01', '2014-02', '2014-03', '2014-04', '2014-05',
#        '2014-06', '2014-07', '2014-08', '2014-09', '2014-10', '2014-11',
#        '2014-12', '2015-01', '2015-02', '2015-03', '2015-04', '2015-05',
#        '2015-06', '2015-07', '2015-08', '2015-09', '2015-10', '2015-11',
#        '2015-12', '2016-01', '2016-02', '2016-03', '2016-04', '2016-05',
# ...

# %%
j = dataset.monthly_GGD()

# %%
j.head()
# Out:
#      Date  BZO  HVB  WB
# 0 2010-01    0   26   0
# 1 2010-02    0   37   0
# 2 2010-03    0   32   0
# 3 2010-04    0   26   0
# 4 2010-05    0   32   0

# %%
q = make_df_shapefile(k)

# %%
q.head()
# Out:
#        Municipality  2010-01  2010-02  2010-03  2010-04  2010-05  2010-06  \
# 0  's-Hertogenbosch        4        4        1        1        3        1
# 1      Alphen-Chaam        0        0        0        0        0        0
# 2          Bernheze        4        1        0        0        1        1
# 3            Boekel        0        0        0        0        1        1
# 4           Boxmeer        0        1        2        1        3        1
#
#    2010-07  2010-08  2010-09  \
# 0        3        5        2
# 1        0        0        0
# 2        0        0        0
# 3        0        0        1
# 4        0        4        0
#
#                          ...                          2016-09  2016-10  \
# 0                        ...                               13        1
# 1                        ...                                0        0
# 2                        ...                                3        3
# ...
